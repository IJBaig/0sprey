# %%
# Example Jupyter Notebook for Feature Exploration

This notebook can be used to explore extracted features, visualize data, and experiment with ML models interactively.

---

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load extracted features
# df = pd.read_csv('../data/flows.csv')
# df.head()

# Example: Visualize packet count distribution
# sns.histplot(df['packet_count'], bins=30)
# plt.show()

# Add your own analysis and visualizations here.
